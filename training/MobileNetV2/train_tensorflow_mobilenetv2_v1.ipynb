# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import MobileNetV2
from setting.setting import *

# %%
data_dir = "../../dataset/processed/v1/training"
val_data_dir = "../../dataset/processed/v1/validation"
model_dir = "../../models/MobileNetV2"
best_model_filename = 'mobilenetv2_best_model_v1.keras'
os.makedirs(model_dir, exist_ok=True)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
).map(lambda x, y: (x / 255.0, y))


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_data_dir,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
).map(lambda x, y: (x / 255.0, y))
# Out:
# Found 21945 files belonging to 26 classes.
# Found 2465 files belonging to 26 classes.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomRotation(0.1),
])

# %%
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))


for layer in base_model.layers:
    layer.trainable = False


model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(26, activation='softmax')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    mode='min',
    verbose=1
)

checkpoint = ModelCheckpoint(
    os.path.join(model_dir, best_model_filename),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
final_total_epochs = 1000
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=final_total_epochs,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.7351 - accuracy: 0.7884
# Epoch 1: val_accuracy improved from -inf to 0.97566, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 174s 204ms/step - loss: 0.7351 - accuracy: 0.7884 - val_loss: 0.0928 - val_accuracy: 0.9757
# Epoch 2/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9201
# Epoch 2: val_accuracy improved from 0.97566 to 0.97809, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 64s 93ms/step - loss: 0.2693 - accuracy: 0.9201 - val_loss: 0.0738 - val_accuracy: 0.9781
# Epoch 3/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.2143 - accuracy: 0.9388
# Epoch 3: val_accuracy improved from 0.97809 to 0.98824, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 84s 121ms/step - loss: 0.2143 - accuracy: 0.9388 - val_loss: 0.0499 - val_accuracy: 0.9882
# Epoch 4/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9438
# Epoch 4: val_accuracy did not improve from 0.98824
# 686/686 [==============================] - 107s 156ms/step - loss: 0.1835 - accuracy: 0.9438 - val_loss: 0.0556 - val_accuracy: 0.9826
# Epoch 5/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9504
# Epoch 5: val_accuracy did not improve from 0.98824
# 686/686 [==============================] - 169s 245ms/step - loss: 0.1701 - accuracy: 0.9504 - val_loss: 0.0599 - val_accuracy: 0.9830
# Epoch 6/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9560
# Epoch 6: val_accuracy did not improve from 0.98824
# 686/686 [==============================] - 160s 231ms/step - loss: 0.1484 - accuracy: 0.9560 - val_loss: 0.0428 - val_accuracy: 0.9882
# Epoch 7/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9579
# Epoch 7: val_accuracy did not improve from 0.98824
# 686/686 [==============================] - 129s 186ms/step - loss: 0.1358 - accuracy: 0.9579 - val_loss: 0.0516 - val_accuracy: 0.9870
# Epoch 8/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9586
# Epoch 8: val_accuracy did not improve from 0.98824
# 686/686 [==============================] - 63s 91ms/step - loss: 0.1310 - accuracy: 0.9586 - val_loss: 0.0527 - val_accuracy: 0.9842
# Epoch 9/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9616
# Epoch 9: val_accuracy did not improve from 0.98824
# 686/686 [==============================] - 87s 125ms/step - loss: 0.1265 - accuracy: 0.9616 - val_loss: 0.0453 - val_accuracy: 0.9878
# Epoch 10/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9648
# Epoch 10: val_accuracy improved from 0.98824 to 0.98864, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 101s 146ms/step - loss: 0.1171 - accuracy: 0.9648 - val_loss: 0.0423 - val_accuracy: 0.9886
# Epoch 11/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9665
# Epoch 11: val_accuracy did not improve from 0.98864
# 686/686 [==============================] - 177s 255ms/step - loss: 0.1133 - accuracy: 0.9665 - val_loss: 0.0484 - val_accuracy: 0.9866
# Epoch 12/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9697
# Epoch 12: val_accuracy improved from 0.98864 to 0.98905, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 172s 249ms/step - loss: 0.1064 - accuracy: 0.9697 - val_loss: 0.0449 - val_accuracy: 0.9890
# Epoch 13/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9697
# Epoch 13: val_accuracy did not improve from 0.98905
# 686/686 [==============================] - 107s 153ms/step - loss: 0.1028 - accuracy: 0.9697 - val_loss: 0.0398 - val_accuracy: 0.9890
# Epoch 14/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9691
# Epoch 14: val_accuracy did not improve from 0.98905
# 686/686 [==============================] - 84s 122ms/step - loss: 0.1045 - accuracy: 0.9691 - val_loss: 0.0412 - val_accuracy: 0.9882
# Epoch 15/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.1018 - accuracy: 0.9694
# Epoch 15: val_accuracy improved from 0.98905 to 0.99108, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 96s 137ms/step - loss: 0.1016 - accuracy: 0.9694 - val_loss: 0.0378 - val_accuracy: 0.9911
# Epoch 16/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9727
# Epoch 16: val_accuracy did not improve from 0.99108
# 686/686 [==============================] - 132s 192ms/step - loss: 0.0901 - accuracy: 0.9727 - val_loss: 0.0463 - val_accuracy: 0.9903
# Epoch 17/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9730
# Epoch 17: val_accuracy did not improve from 0.99108
# 686/686 [==============================] - 165s 237ms/step - loss: 0.0940 - accuracy: 0.9730 - val_loss: 0.0433 - val_accuracy: 0.9907
# Epoch 18/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9758
# Epoch 18: val_accuracy did not improve from 0.99108
# 686/686 [==============================] - 152s 220ms/step - loss: 0.0809 - accuracy: 0.9758 - val_loss: 0.0465 - val_accuracy: 0.9903
# Epoch 19/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0784 - accuracy: 0.9758
# Epoch 19: val_accuracy did not improve from 0.99108
# 686/686 [==============================] - 90s 130ms/step - loss: 0.0783 - accuracy: 0.9758 - val_loss: 0.0409 - val_accuracy: 0.9899
# Epoch 20/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9748
# Epoch 20: val_accuracy did not improve from 0.99108
# 686/686 [==============================] - 119s 172ms/step - loss: 0.0857 - accuracy: 0.9748 - val_loss: 0.0335 - val_accuracy: 0.9903
# Epoch 21/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9782
# Epoch 21: val_accuracy did not improve from 0.99108
# 686/686 [==============================] - 115s 167ms/step - loss: 0.0736 - accuracy: 0.9782 - val_loss: 0.0392 - val_accuracy: 0.9890
# Epoch 22/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9778
# Epoch 22: val_accuracy improved from 0.99108 to 0.99148, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 174s 252ms/step - loss: 0.0723 - accuracy: 0.9778 - val_loss: 0.0441 - val_accuracy: 0.9915
# Epoch 23/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9758
# Epoch 23: val_accuracy did not improve from 0.99148
# 686/686 [==============================] - 167s 241ms/step - loss: 0.0828 - accuracy: 0.9758 - val_loss: 0.0422 - val_accuracy: 0.9907
# Epoch 24/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9776
# Epoch 24: val_accuracy did not improve from 0.99148
# 686/686 [==============================] - 136s 197ms/step - loss: 0.0735 - accuracy: 0.9777 - val_loss: 0.0508 - val_accuracy: 0.9903
# Epoch 25/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9778
# Epoch 25: val_accuracy did not improve from 0.99148
# 686/686 [==============================] - 66s 95ms/step - loss: 0.0728 - accuracy: 0.9778 - val_loss: 0.0451 - val_accuracy: 0.9915
# Epoch 26/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9798
# Epoch 26: val_accuracy did not improve from 0.99148
# 686/686 [==============================] - 86s 123ms/step - loss: 0.0642 - accuracy: 0.9798 - val_loss: 0.0404 - val_accuracy: 0.9895
# Epoch 27/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9792
# Epoch 27: val_accuracy improved from 0.99148 to 0.99189, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 78s 113ms/step - loss: 0.0732 - accuracy: 0.9792 - val_loss: 0.0446 - val_accuracy: 0.9919
# Epoch 28/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9783
# Epoch 28: val_accuracy did not improve from 0.99189
# 686/686 [==============================] - 192s 278ms/step - loss: 0.0761 - accuracy: 0.9783 - val_loss: 0.0458 - val_accuracy: 0.9890
# Epoch 29/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9791
# Epoch 29: val_accuracy did not improve from 0.99189
# 686/686 [==============================] - 178s 257ms/step - loss: 0.0722 - accuracy: 0.9791 - val_loss: 0.0591 - val_accuracy: 0.9899
# Epoch 30/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0609 - accuracy: 0.9808
# Epoch 30: val_accuracy did not improve from 0.99189
# 686/686 [==============================] - 160s 232ms/step - loss: 0.0608 - accuracy: 0.9809 - val_loss: 0.0587 - val_accuracy: 0.9911
# Epoch 31/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0600 - accuracy: 0.9812
# Epoch 31: val_accuracy did not improve from 0.99189
# 686/686 [==============================] - 97s 139ms/step - loss: 0.0600 - accuracy: 0.9812 - val_loss: 0.0470 - val_accuracy: 0.9915
# Epoch 32/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9816
# Epoch 32: val_accuracy improved from 0.99189 to 0.99391, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 686/686 [==============================] - 82s 119ms/step - loss: 0.0611 - accuracy: 0.9816 - val_loss: 0.0355 - val_accuracy: 0.9939
# Epoch 33/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9805
# Epoch 33: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 156s 225ms/step - loss: 0.0681 - accuracy: 0.9805 - val_loss: 0.0362 - val_accuracy: 0.9911
# Epoch 34/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9825
# Epoch 34: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 166s 239ms/step - loss: 0.0598 - accuracy: 0.9825 - val_loss: 0.0422 - val_accuracy: 0.9915
# Epoch 35/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9836
# Epoch 35: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 97s 139ms/step - loss: 0.0564 - accuracy: 0.9836 - val_loss: 0.0487 - val_accuracy: 0.9903
# Epoch 36/1000
# 685/686 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9832
# Epoch 36: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 62s 89ms/step - loss: 0.0555 - accuracy: 0.9832 - val_loss: 0.0451 - val_accuracy: 0.9911
# Epoch 37/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9832
# Epoch 37: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 73s 104ms/step - loss: 0.0581 - accuracy: 0.9832 - val_loss: 0.0500 - val_accuracy: 0.9915
# Epoch 38/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9826
# Epoch 38: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 84s 122ms/step - loss: 0.0577 - accuracy: 0.9826 - val_loss: 0.0416 - val_accuracy: 0.9923
# Epoch 39/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9838
# Epoch 39: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 190s 276ms/step - loss: 0.0549 - accuracy: 0.9838 - val_loss: 0.0429 - val_accuracy: 0.9903
# Epoch 40/1000
# 686/686 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9831
# Epoch 40: val_accuracy did not improve from 0.99391
# 686/686 [==============================] - 190s 276ms/step - loss: 0.0570 - accuracy: 0.9831 - val_loss: 0.0456 - val_accuracy: 0.9915
# Epoch 40: early stopping

# %%
print(f"Mô hình tốt nhất đã được lưu tại: {os.path.join(model_dir, best_model_filename)}")
# Out:
# Mô hình tốt nhất đã được lưu tại: ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import random
import numpy as np
import string
import matplotlib.pyplot as plt

val_images, val_labels = next(iter(val_ds))

random_index = random.randint(0, BATCH_SIZE - 1)
img = val_images[random_index]
true_label = val_labels[random_index]


pred = model.predict(tf.expand_dims(img, axis=0))
pred_label = string.ascii_uppercase[np.argmax(pred)]
true_label_str = string.ascii_uppercase[np.argmax(true_label)]

plt.imshow(img)
plt.title(f"True: {true_label_str}, Pred: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
