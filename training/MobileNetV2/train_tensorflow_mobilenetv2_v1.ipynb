# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import MobileNetV2
from setting.setting import *

# %%
data_dir = "../../dataset/processed/v1/training"
val_data_dir = "../../dataset/processed/v1/validation"
model_dir = "../../models/MobileNetV2"
best_model_filename = 'mobilenetv2_best_model_v1.keras'
os.makedirs(model_dir, exist_ok=True)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
).map(lambda x, y: (x / 255.0, y))


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_data_dir,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical',
).map(lambda x, y: (x / 255.0, y))
# Out:
# Found 21945 files belonging to 26 classes.
# Found 2465 files belonging to 26 classes.

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomRotation(0.1),
])

# %%
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))


for layer in base_model.layers:
    layer.trainable = False


model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(26, activation='softmax')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    mode='min',
    verbose=1
)

checkpoint = ModelCheckpoint(
    os.path.join(model_dir, best_model_filename),
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
final_total_epochs = 1000
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=final_total_epochs,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.8041
# Epoch 1: val_accuracy improved from -inf to 0.97728, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 112s 305ms/step - loss: 0.6757 - accuracy: 0.8041 - val_loss: 0.0859 - val_accuracy: 0.9773
# Epoch 2/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.9342
# Epoch 2: val_accuracy improved from 0.97728 to 0.98174, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 111s 320ms/step - loss: 0.2349 - accuracy: 0.9342 - val_loss: 0.0587 - val_accuracy: 0.9817
# Epoch 3/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9468
# Epoch 3: val_accuracy improved from 0.98174 to 0.98337, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 161s 451ms/step - loss: 0.1864 - accuracy: 0.9468 - val_loss: 0.0528 - val_accuracy: 0.9834
# Epoch 4/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9571
# Epoch 4: val_accuracy improved from 0.98337 to 0.98540, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 171s 487ms/step - loss: 0.1503 - accuracy: 0.9571 - val_loss: 0.0477 - val_accuracy: 0.9854
# Epoch 5/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.1366 - accuracy: 0.9620
# Epoch 5: val_accuracy improved from 0.98540 to 0.98702, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 166s 472ms/step - loss: 0.1364 - accuracy: 0.9620 - val_loss: 0.0517 - val_accuracy: 0.9870
# Epoch 6/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9651
# Epoch 6: val_accuracy improved from 0.98702 to 0.98783, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 167s 468ms/step - loss: 0.1186 - accuracy: 0.9651 - val_loss: 0.0411 - val_accuracy: 0.9878
# Epoch 7/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.1118 - accuracy: 0.9668
# Epoch 7: val_accuracy improved from 0.98783 to 0.98824, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 166s 474ms/step - loss: 0.1117 - accuracy: 0.9668 - val_loss: 0.0447 - val_accuracy: 0.9882
# Epoch 8/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0994 - accuracy: 0.9694
# Epoch 8: val_accuracy improved from 0.98824 to 0.99067, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 55s 149ms/step - loss: 0.0995 - accuracy: 0.9693 - val_loss: 0.0392 - val_accuracy: 0.9907
# Epoch 9/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9710
# Epoch 9: val_accuracy did not improve from 0.99067
# 343/343 [==============================] - 101s 292ms/step - loss: 0.0944 - accuracy: 0.9710 - val_loss: 0.0481 - val_accuracy: 0.9862
# Epoch 10/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9721
# Epoch 10: val_accuracy improved from 0.99067 to 0.99148, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 66s 181ms/step - loss: 0.0900 - accuracy: 0.9722 - val_loss: 0.0456 - val_accuracy: 0.9915
# Epoch 11/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0879 - accuracy: 0.9737
# Epoch 11: val_accuracy did not improve from 0.99148
# 343/343 [==============================] - 69s 199ms/step - loss: 0.0878 - accuracy: 0.9737 - val_loss: 0.0539 - val_accuracy: 0.9886
# Epoch 12/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9772
# Epoch 12: val_accuracy did not improve from 0.99148
# 343/343 [==============================] - 166s 474ms/step - loss: 0.0776 - accuracy: 0.9773 - val_loss: 0.0429 - val_accuracy: 0.9895
# Epoch 13/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9736
# Epoch 13: val_accuracy did not improve from 0.99148
# 343/343 [==============================] - 165s 472ms/step - loss: 0.0852 - accuracy: 0.9736 - val_loss: 0.0398 - val_accuracy: 0.9899
# Epoch 14/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0809 - accuracy: 0.9750
# Epoch 14: val_accuracy improved from 0.99148 to 0.99189, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 169s 491ms/step - loss: 0.0808 - accuracy: 0.9750 - val_loss: 0.0332 - val_accuracy: 0.9919
# Epoch 15/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9770
# Epoch 15: val_accuracy did not improve from 0.99189
# 343/343 [==============================] - 170s 484ms/step - loss: 0.0782 - accuracy: 0.9770 - val_loss: 0.0329 - val_accuracy: 0.9919
# Epoch 16/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9773
# Epoch 16: val_accuracy did not improve from 0.99189
# 343/343 [==============================] - 166s 473ms/step - loss: 0.0751 - accuracy: 0.9773 - val_loss: 0.0381 - val_accuracy: 0.9907
# Epoch 17/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0740 - accuracy: 0.9778
# Epoch 17: val_accuracy improved from 0.99189 to 0.99229, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 90s 241ms/step - loss: 0.0739 - accuracy: 0.9779 - val_loss: 0.0324 - val_accuracy: 0.9923
# Epoch 18/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9805
# Epoch 18: val_accuracy did not improve from 0.99229
# 343/343 [==============================] - 55s 158ms/step - loss: 0.0618 - accuracy: 0.9805 - val_loss: 0.0456 - val_accuracy: 0.9899
# Epoch 19/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9762
# Epoch 19: val_accuracy did not improve from 0.99229
# 343/343 [==============================] - 115s 317ms/step - loss: 0.0755 - accuracy: 0.9762 - val_loss: 0.0412 - val_accuracy: 0.9915
# Epoch 20/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0619 - accuracy: 0.9802
# Epoch 20: val_accuracy did not improve from 0.99229
# 343/343 [==============================] - 46s 131ms/step - loss: 0.0619 - accuracy: 0.9802 - val_loss: 0.0425 - val_accuracy: 0.9915
# Epoch 21/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9805
# Epoch 21: val_accuracy improved from 0.99229 to 0.99351, saving model to ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras
# 343/343 [==============================] - 169s 483ms/step - loss: 0.0636 - accuracy: 0.9805 - val_loss: 0.0399 - val_accuracy: 0.9935
# Epoch 22/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9822
# Epoch 22: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 170s 485ms/step - loss: 0.0592 - accuracy: 0.9822 - val_loss: 0.0475 - val_accuracy: 0.9911
# Epoch 23/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9809
# Epoch 23: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 190s 543ms/step - loss: 0.0653 - accuracy: 0.9809 - val_loss: 0.0332 - val_accuracy: 0.9931
# Epoch 24/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9839
# Epoch 24: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 176s 500ms/step - loss: 0.0527 - accuracy: 0.9839 - val_loss: 0.0461 - val_accuracy: 0.9899
# Epoch 25/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9841
# Epoch 25: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 170s 484ms/step - loss: 0.0527 - accuracy: 0.9841 - val_loss: 0.0448 - val_accuracy: 0.9882
# Epoch 26/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9818
# Epoch 26: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 89s 249ms/step - loss: 0.0611 - accuracy: 0.9818 - val_loss: 0.0386 - val_accuracy: 0.9899
# Epoch 27/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9830
# Epoch 27: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 125s 362ms/step - loss: 0.0573 - accuracy: 0.9830 - val_loss: 0.0402 - val_accuracy: 0.9927
# Epoch 28/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9840
# Epoch 28: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 61s 176ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0358 - val_accuracy: 0.9923
# Epoch 29/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9845
# Epoch 29: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 185s 529ms/step - loss: 0.0499 - accuracy: 0.9845 - val_loss: 0.0356 - val_accuracy: 0.9915
# Epoch 30/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9862
# Epoch 30: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 184s 515ms/step - loss: 0.0464 - accuracy: 0.9862 - val_loss: 0.0384 - val_accuracy: 0.9911
# Epoch 31/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0498 - accuracy: 0.9854
# Epoch 31: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 169s 482ms/step - loss: 0.0498 - accuracy: 0.9854 - val_loss: 0.0374 - val_accuracy: 0.9911
# Epoch 32/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9834
# Epoch 32: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 169s 481ms/step - loss: 0.0506 - accuracy: 0.9834 - val_loss: 0.0404 - val_accuracy: 0.9927
# Epoch 33/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9857
# Epoch 33: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 170s 475ms/step - loss: 0.0474 - accuracy: 0.9857 - val_loss: 0.0449 - val_accuracy: 0.9919
# Epoch 34/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9870
# Epoch 34: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 84s 234ms/step - loss: 0.0468 - accuracy: 0.9870 - val_loss: 0.0399 - val_accuracy: 0.9923
# Epoch 35/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9852
# Epoch 35: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 55s 159ms/step - loss: 0.0483 - accuracy: 0.9852 - val_loss: 0.0424 - val_accuracy: 0.9915
# Epoch 36/1000
# 343/343 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9853
# Epoch 36: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 131s 372ms/step - loss: 0.0501 - accuracy: 0.9853 - val_loss: 0.0407 - val_accuracy: 0.9927
# Epoch 37/1000
# 342/343 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9860
# Epoch 37: val_accuracy did not improve from 0.99351
# 343/343 [==============================] - 151s 436ms/step - loss: 0.0453 - accuracy: 0.9860 - val_loss: 0.0391 - val_accuracy: 0.9911
# Epoch 37: early stopping

# %%
print(f"Mô hình tốt nhất đã được lưu tại: {os.path.join(model_dir, best_model_filename)}")
# Out:
# Mô hình tốt nhất đã được lưu tại: ../../models/MobileNetV2\mobilenetv2_best_model_v1.keras

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import random
import numpy as np
import string
import matplotlib.pyplot as plt

val_images, val_labels = next(iter(val_ds))

random_index = random.randint(0, BATCH_SIZE - 1)
img = val_images[random_index]
true_label = val_labels[random_index]


pred = model.predict(tf.expand_dims(img, axis=0))
pred_label = string.ascii_uppercase[np.argmax(pred)]
true_label_str = string.ascii_uppercase[np.argmax(true_label)]

plt.imshow(img)
plt.title(f"True: {true_label_str}, Pred: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 687ms/step
